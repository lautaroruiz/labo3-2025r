# %%
import psutil
import pandas as pd
import numpy as np
from src.utils.utils import get_base_dir
base_dir = get_base_dir()
base_dir
# Out:
# WindowsPath('C:/Users/lauta/Desktop/Lautaro/maestria_ds/labo3/repo-entrega')

# %% [markdown]
# ### 1. Carga de datos

# %%
sell_in_features = pd.read_feather(base_dir / "data/interim/sell_in_completo_con_fe.feather")

# %% [markdown]
# ### 2. Creación del target - dicisión de bases - post procesamiento

# %%
# Variable respuesta
sell_in_features["target"] = sell_in_features["tn"] - sell_in_features["venta_t-2"]

# %%
# Variable para importancia registro durante el entrenamiento
sell_in_features["peso_entrenamiento"] = np.log1p(np.abs(sell_in_features["tn"]))

# %%
# Listado de variables extras consideradas para el modelado
new_cols = ['venta_t-2', 'venta_t-3', 'venta_t-6',
       'venta_t-9', 'venta_t-12', 'venta_t-24', 'media_3m', 'std_3m',
       'suma_3m', 'max_3m', 'min_3m', 'media_6m', 'std_6m', 'suma_6m',
       'max_6m', 'min_6m', 'media_9m', 'std_9m', 'suma_9m', 'max_9m', 'min_9m',
       'media_12m', 'std_12m', 'suma_12m', 'max_12m', 'min_12m', 'media_24m',
       'std_24m', 'suma_24m', 'max_24m', 'min_24m', 'pct_change_2_4m',
       'pct_change_4_7m', 'tendencia_2_4m', 'tendencia_4_6m', 'venta_año_ant',
       'mes_sin', 'mes_cos', 'trimestre_sin', 'trimestre_cos', 'es_enero',
       'es_diciembre', 'es_verano', 'es_invierno', 'producto_media_historica',
       'producto_volatilidad', 'cliente_media_historica', 'momentum_3m',
       'momentum_6m', 'aceleracion', 'categoria_media', 'vs_categoria',
       'marca_media', 'vs_marca', 'meses_sin_venta', 'frecuencia_compras_12m',
       'VarMensualGral', 'VarMensualAlim', 'IndiceMensualGral',
       'IndiceMensualAlim', 'dolar']

# %%
# Definir listado de variables
numerical_features = new_cols + ["mes", "año", "trimestre", "a_predecir"]
categorical_features = ["product_id", "customer_id", 'cat1', 'cat2', 'cat3', 'brand', 'descripcion']
model_features = numerical_features + categorical_features

# Convertir variables categóricas
for cat_col in categorical_features:
    sell_in_features[cat_col] = sell_in_features[cat_col].astype("category")

# %%
# crear los conjuntos de datos de train, validation y predict
df_predict = sell_in_features[sell_in_features["periodo"]==202002].copy()
df_train = sell_in_features[sell_in_features["periodo"]<201907].copy()
df_validation = sell_in_features[(sell_in_features["periodo"]>=201907) & (sell_in_features["periodo"]<202001)].copy()
del sell_in_features

# %%
# check memoria ram
mem = psutil.virtual_memory()
print(f"Memoria RAM disponible: {mem.available / (1024**3):.2f} GB")
# Out:
# Memoria RAM disponible: 17.47 GB

# %%
# dimensiones particiones
df_predict.shape, df_train.shape, df_validation.shape
# Out:
# ((465660, 79), (15599943, 79), (4277589, 79))

# %%
# check nulos
df_train.target.isna().sum(), df_validation.target.isna().sum(), df_predict.target.isna().sum()
# Out:
# (np.int64(1319082), np.int64(149269), np.int64(465660))

# %%
# eliminar target nan de train y validation
df_train = df_train[df_train["target"].notna()].copy().reset_index(drop=True)
df_validation = df_validation[df_validation["target"].notna()].copy().reset_index(drop=True)

# %%
# filtrar datos posteriores a julio 2017
df_train = df_train[df_train["periodo"]>201707].copy().reset_index(drop=True)

# %%
# dimensiones particiones post-procesamiento
df_predict.shape, df_train.shape, df_validation.shape
# Out:
# ((465660, 79), (12516572, 79), (4128320, 79))

# %% [markdown]
# ### 3. Check caso

# %%
perfil = (df_train["product_id"]==20001) & (df_train["customer_id"]==10001)
df_train[perfil].sort_values(by="periodo", ascending=True)
# Out:
#     periodo product_id customer_id         tn      fecha cat1         cat2  \
# 0    201708      20001       10001   43.33930 2017-08-01   HC  ROPA LAVADO
# 1    201709      20001       10001  289.35024 2017-09-01   HC  ROPA LAVADO
# 2    201710      20001       10001  222.11389 2017-10-01   HC  ROPA LAVADO
# 3    201711      20001       10001  111.54944 2017-11-01   HC  ROPA LAVADO
# 4    201712      20001       10001  131.27150 2017-12-01   HC  ROPA LAVADO
# 5    201801      20001       10001   49.61857 2018-01-01   HC  ROPA LAVADO
# 6    201802      20001       10001   88.44065 2018-02-01   HC  ROPA LAVADO
# 7    201803      20001       10001  214.72336 2018-03-01   HC  ROPA LAVADO
# 8    201804      20001       10001  132.83419 2018-04-01   HC  ROPA LAVADO
# 9    201805      20001       10001  165.73507 2018-05-01   HC  ROPA LAVADO
# 10   201806      20001       10001   92.29410 2018-06-01   HC  ROPA LAVADO
# 11   201807      20001       10001  256.05760 2018-07-01   HC  ROPA LAVADO
# 12   201808      20001       10001  139.24210 2018-08-01   HC  ROPA LAVADO
# 13   201809      20001       10001  358.57922 2018-09-01   HC  ROPA LAVADO
# 14   201810      20001       10001  245.21397 2018-10-01   HC  ROPA LAVADO
# 15   201811      20001       10001  241.02438 2018-11-01   HC  ROPA LAVADO
# 16   201812      20001       10001  254.62373 2018-12-01   HC  ROPA LAVADO
# 17   201901      20001       10001  386.60688 2019-01-01   HC  ROPA LAVADO
# 18   201902      20001       10001  309.90610 2019-02-01   HC  ROPA LAVADO
# 19   201903      20001       10001  130.54927 2019-03-01   HC  ROPA LAVADO
# 20   201904      20001       10001  364.37071 2019-04-01   HC  ROPA LAVADO
# 21   201905      20001       10001  439.90647 2019-05-01   HC  ROPA LAVADO
# 22   201906      20001       10001   65.92436 2019-06-01   HC  ROPA LAVADO
#
#        cat3  brand  sku_size  ...     vs_marca  meses_sin_venta  \
# 0   Liquido  ARIEL    3000.0  ...   320.014496              7.0
# 1   Liquido  ARIEL    3000.0  ...   330.778138              8.0
# 2   Liquido  ARIEL    3000.0  ...   146.786744              9.0
# 3   Liquido  ARIEL    3000.0  ...   859.945490             10.0
# 4   Liquido  ARIEL    3000.0  ...   619.444203             11.0
# 5   Liquido  ARIEL    3000.0  ...   338.722530             11.0
# 6   Liquido  ARIEL    3000.0  ...   528.466037             11.0
# 7   Liquido  ARIEL    3000.0  ...   219.667734             11.0
# 8   Liquido  ARIEL    3000.0  ...   382.328140             11.0
# 9   Liquido  ARIEL    3000.0  ...   565.000193             11.0
# 10  Liquido  ARIEL    3000.0  ...   573.813653             11.0
# 11  Liquido  ARIEL    3000.0  ...   599.322716             11.0
# 12  Liquido  ARIEL    3000.0  ...   407.446356             11.0
# 13  Liquido  ARIEL    3000.0  ...  1111.951320             11.0
# 14  Liquido  ARIEL    3000.0  ...   558.398771             11.0
# 15  Liquido  ARIEL    3000.0  ...  1728.346162             11.0
# 16  Liquido  ARIEL    3000.0  ...   979.181881             11.0
# 17  Liquido  ARIEL    3000.0  ...  1149.442154             11.0
# 18  Liquido  ARIEL    3000.0  ...  1432.555213             11.0
# 19  Liquido  ARIEL    3000.0  ...  2593.691458             11.0
# 20  Liquido  ARIEL    3000.0  ...  2087.911564             11.0
# 21  Liquido  ARIEL    3000.0  ...   737.607694             11.0
# 22  Liquido  ARIEL    3000.0  ...  2027.657939             11.0
#
#    frecuencia_compras_12m  VarMensualGral  VarMensualAlim  IndiceMensualGral  \
# 0                     6.0             1.4             2.1           115.3819
# 1                     7.0             1.9             1.8           117.5719
# 2                     8.0             1.5             1.5           119.3528
# 3                     9.0             1.4             1.2           120.9940
# 4                    10.0             3.1             0.7           124.7956
# 5                    11.0             1.8             2.1           126.9887
# 6                    12.0             2.4             2.2           130.0606
# 7                    12.0             2.3             2.3           133.1054
# 8                    12.0             2.7             1.2           136.7512
# 9                    12.0             2.1             3.3           139.5893
# 10                   12.0             3.7             5.2           144.8053
# 11                   12.0             3.1             4.0           149.2966
# 12                   12.0             3.9             4.0           155.1034
# 13                   12.0             6.5             7.0           165.2383
# 14                   12.0             5.4             5.9           174.1473
# 15                   12.0             3.2             3.4           179.6388
# 16                   12.0             2.6             1.7           184.2552
# 17                   12.0             2.9             3.4           189.6101
# 18                   12.0             3.8             5.7           196.7501
# 19                   12.0             4.7             6.0           205.9571
# 20                   12.0             3.4             2.5           213.0517
# 21                   12.0             3.1             2.4           219.5691
# 22                   12.0             2.7             2.6           225.5370
#
#     IndiceMensualAlim      dolar     target  peso_entrenamiento
# 0            114.3467  17.718636  -84.70862            3.791871
# 1            116.4048  17.549524  188.14313            5.671088
# 2            118.1646  17.763333  178.77459            5.407682
# 3            119.5688  17.787000 -177.80080            4.723393
# 4            120.3600  18.045789  -90.84239            4.884857
# 5            122.8752  19.357273  -61.93087            3.924319
# 6            125.5566  20.150556  -42.83085            4.493575
# 7            128.4690  20.558000  165.10479            5.373997
# 8            129.9559  20.537368   44.39354            4.896602
# 9            134.2019  24.234286  -48.98829            5.116406
# 10           141.1510  27.259000  -40.54009            4.535757
# 11           146.7848  28.288571   90.32253            5.549300
# 12           152.6743  30.910909   46.94800            4.943370
# 13           163.3911  39.415000  102.52162            5.884935
# 14           173.0007  38.079545  105.97187            5.506201
# 15           178.8975  37.492105 -117.55484            5.489038
# 16           181.9359  38.857778    9.40976            5.543707
# 17           188.0357  38.436364  145.58250            5.959992
# 18           198.7818  39.451000   55.28237            5.739491
# 19           210.6280  42.548947 -256.05761            4.879381
# 20           215.9985  44.360000   54.46461            5.900912
# 21           221.2588  46.082273  309.35720            6.088833
# 22           226.9033  44.952778 -298.44635            4.203563
#
# [23 rows x 79 columns]

# %%
perfil = (df_validation["product_id"]==20001) & (df_validation["customer_id"]==10001)
df_validation[perfil].sort_values(by="periodo", ascending=True)
# Out:
#    periodo product_id customer_id         tn      fecha cat1         cat2  \
# 0   201907      20001       10001  144.78714 2019-07-01   HC  ROPA LAVADO
# 1   201908      20001       10001   33.63991 2019-08-01   HC  ROPA LAVADO
# 2   201909      20001       10001  109.05244 2019-09-01   HC  ROPA LAVADO
# 3   201910      20001       10001  176.02980 2019-10-01   HC  ROPA LAVADO
# 4   201911      20001       10001  236.65556 2019-11-01   HC  ROPA LAVADO
# 5   201912      20001       10001  180.21938 2019-12-01   HC  ROPA LAVADO
#
#       cat3  brand  sku_size  ...     vs_marca  meses_sin_venta  \
# 0  Liquido  ARIEL    3000.0  ...  2841.417597             11.0
# 1  Liquido  ARIEL    3000.0  ...   662.989654             11.0
# 2  Liquido  ARIEL    3000.0  ...  1042.743891             11.0
# 3  Liquido  ARIEL    3000.0  ...   337.124310             11.0
# 4  Liquido  ARIEL    3000.0  ...   856.082875             11.0
# 5  Liquido  ARIEL    3000.0  ...  1728.614293             11.0
#
#   frecuencia_compras_12m  VarMensualGral  VarMensualAlim  IndiceMensualGral  \
# 0                   12.0             2.2             2.3           230.4940
# 1                   12.0             4.0             4.5           239.6077
# 2                   12.0             5.9             5.7           253.7102
# 3                   12.0             3.3             2.5           262.0661
# 4                   12.0             4.3             5.3           273.2158
# 5                   12.0             3.7             3.1           283.4442
#
#    IndiceMensualAlim      dolar     target  peso_entrenamiento
# 0           232.0295  43.751429 -295.11933            4.982148
# 1           242.5051  54.641429  -32.28445            3.545006
# 2           256.3757  58.790000  -35.73470            4.700957
# 3           262.6603  61.399091  142.38989            5.176318
# 4           276.6339  63.011579  127.60312            5.470822
# 5           285.2970  63.009474    4.18958            5.199708
#
# [6 rows x 79 columns]

# %%
perfil = (df_predict["product_id"]==20001) & (df_predict["customer_id"]==10001)
df_predict[perfil].sort_values(by="periodo", ascending=True)
# Out:
#     periodo product_id customer_id  tn      fecha cat1         cat2     cat3  \
# 37   202002      20001       10001 NaN 2020-02-01   HC  ROPA LAVADO  Liquido
#
#     brand  sku_size  ...    vs_marca  meses_sin_venta frecuencia_compras_12m  \
# 37  ARIEL    3000.0  ...  1901.95275             11.0                   12.0
#
#     VarMensualGral  VarMensualAlim  IndiceMensualGral  IndiceMensualAlim  \
# 37             2.0             2.7            295.666           306.6182
#
#      dolar  target  peso_entrenamiento
# 37  63.056     NaN                 NaN
#
# [1 rows x 79 columns]

# %%
# check memoria ram
mem = psutil.virtual_memory()
print(f"Memoria RAM disponible: {mem.available / (1024**3):.2f} GB")
# Out:
# Memoria RAM disponible: 15.44 GB

# %% [markdown]
# ## 4. Guardar particiones para modelado

# %%
df_train.to_feather(base_dir / "data/processed/df_train.feather")
df_validation.to_feather(base_dir / "data/processed/df_validation.feather")
df_predict.to_feather(base_dir / "data/processed/df_predict.feather")
